# %% [markdown]
# # Wikipedia Web Scraping

# %%
import pandas as pd

# %%
pd.set_option('display.max.rows', 150)

# %%
original_df = pd.read_csv(r"C:\Users\fokike\OneDrive\Data Analytics Portfolio\Companies.csv")

original_df
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                           ExxonMobil
# 3      4                                Apple
# 4      5                   UnitedHealth Group
# 5      6                           CVS Health
# 6      7                   Berkshire Hathaway
# 7      8                             Alphabet
# 8      9                 McKesson Corporation
# 9     10                  Chevron Corporation
# 10    11                    AmerisourceBergen
# 11    12                               Costco
# 12    13                            Microsoft
# 13    14                      Cardinal Health
# 14    15                                Cigna
# 15    16                   Marathon Petroleum
# 16    17                          Phillips 66
# 17    18                        Valero Energy
# 18    19                   Ford Motor Company
# ...

# %%
df[df['Rank']< 10]
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3            ExxonMobil              Petroleum industry
# 3     4                 Apple            Electronics industry
# 4     5    UnitedHealth Group                      Healthcare
# 5     6            CVS Health                      Healthcare
# 6     7    Berkshire Hathaway                    Conglomerate
# 7     8              Alphabet  Technology and cloud computing
# 8     9  McKesson Corporation                          Health
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# 2                413,680          44.8%     62,000              Spring, Texas
# ...

# %%
specific_industries = ['Retail','Healthcare']

df[df['Industry'].isin(specific_industries)]
# Out:
#     Rank                Name    Industry Revenue (USD millions)  \
# 0      1             Walmart      Retail                611,289
# 4      5  UnitedHealth Group  Healthcare                324,162
# 5      6          CVS Health  Healthcare                322,467
# 11    12              Costco      Retail                226,954
# 13    14     Cardinal Health  Healthcare                181,364
# 19    20      The Home Depot      Retail                157,403
# 21    22     Elevance Health  Healthcare                156,595
# 23    24              Kroger      Retail                148,258
# 24    25             Centene  Healthcare                144,547
# 32    33  Target Corporation      Retail                109,120
# 38    39              Lowe's      Retail                 97,059
# 52    53          Albertsons      Retail                 77,650
# 67    68      HCA Healthcare  Healthcare                 60,233
# 79    80              Publix      Retail                 54,942
# ...

# %%
df[df['Name'].str.contains('Energy')]
# Out:
#     Rank                      Name            Industry Revenue (USD millions)  \
# 17    18             Valero Energy  Petroleum industry                171,189
# 42    43  Energy Transfer Partners  Petroleum industry                 89,876
# 93    94                PBF Energy  Petroleum industry                 46,830
#
#    Revenue growth Employees                       Headquarters
# 17          58.0%     9,743                 San Antonio, Texas
# 42          33.3%    12,565                      Dallas, Texas
# 93          71.8%     3,616  Parsippany–Troy Hills, New Jersey

# %%
df2 = df.set_index('Industry')
df2
# Out:
#                                     Rank                                 Name  \
# Industry
# Retail                                 1                              Walmart
# Retail and cloud computing             2                               Amazon
# Petroleum industry                     3                           ExxonMobil
# Electronics industry                   4                                Apple
# Healthcare                             5                   UnitedHealth Group
# Healthcare                             6                           CVS Health
# Conglomerate                           7                   Berkshire Hathaway
# Technology and cloud computing         8                             Alphabet
# Health                                 9                 McKesson Corporation
# Petroleum industry                    10                  Chevron Corporation
# Pharmaceutical industry               11                    AmerisourceBergen
# ...

# %%
df2.filter(items = ['Name','Headquarters'])
# Out:
#                                                                    Name  \
# Industry
# Retail                                                          Walmart
# Retail and cloud computing                                       Amazon
# Petroleum industry                                           ExxonMobil
# Electronics industry                                              Apple
# Healthcare                                           UnitedHealth Group
# Healthcare                                                   CVS Health
# Conglomerate                                         Berkshire Hathaway
# Technology and cloud computing                                 Alphabet
# Health                                             McKesson Corporation
# Petroleum industry                                  Chevron Corporation
# Pharmaceutical industry                               AmerisourceBergen
# Retail                                                           Costco
# ...

# %%
df2[df2['Rank'] > 40].sort_values(by=['Industry','Name'], ascending = [True, False])
# Out:
#                                   Rank                                 Name  \
# Industry
# Aerospace and defense               62                      Lockheed Martin
# Aerospace and defense               60                               Boeing
# Agriculture cooperative             92                                  CHS
# Agriculture manufacturing           83                           John Deere
# Airline                             98                      United Airlines
# Airline                             87                      Delta Air Lines
# Airline                             91                    American Airlines
# Apparel                             95                                 Nike
# Automotive and energy               50                                Tesla
# Beverage                            46                              PepsiCo
# Chemical industry                   77                 Dow Chemical Company
# ...

# %%
df2.loc['Retail']
# Out:
#           Rank                Name Revenue (USD millions) Revenue growth  \
# Industry
# Retail       1             Walmart                611,289           6.7%
# Retail      12              Costco                226,954          15.8%
# Retail      20      The Home Depot                157,403           4.1%
# Retail      24              Kroger                148,258           7.5%
# Retail      33  Target Corporation                109,120           2.9%
# Retail      39              Lowe's                 97,059           0.8%
# Retail      53          Albertsons                 77,650           8.0%
# Retail      80              Publix                 54,942          13.5%
# Retail      89                 TJX                 49,936           2.9%
# Retail      96            Best Buy                 46,298          10.6%
#
#           Employees                 Headquarters
# Industry
# Retail    2,100,000        Bentonville, Arkansas
# ...

# %%
df2.iloc[6]
# Out:
# Rank                                       7
# Name                      Berkshire Hathaway
# Revenue (USD millions)               302,089
# Revenue growth                          9.4%
# Employees                            383,000
# Headquarters                 Omaha, Nebraska
# Name: Conglomerate, dtype: object

# %%
df2.reset_index(inplace = True)

# %%
df2
# Out:
#                               Industry  Rank  \
# 0                               Retail     1
# 1           Retail and cloud computing     2
# 2                   Petroleum industry     3
# 3                 Electronics industry     4
# 4                           Healthcare     5
# 5                           Healthcare     6
# 6                         Conglomerate     7
# 7       Technology and cloud computing     8
# 8                               Health     9
# 9                   Petroleum industry    10
# 10             Pharmaceutical industry    11
# 11                              Retail    12
# 12      Technology and cloud computing    13
# 13                          Healthcare    14
# 14                    Health insurance    15
# 15                  Petroleum industry    16
# 16                  Petroleum industry    17
# 17                  Petroleum industry    18
# 18                 Automotive industry    19
# 19                              Retail    20
# ...

# %%
df2.set_index(['Industry','Name'], inplace =True)

# %%
df2
# Out:
#                                                                         Rank  \
# Industry                           Name
# Retail                             Walmart                                 1
# Retail and cloud computing         Amazon                                  2
# Petroleum industry                 ExxonMobil                              3
# Electronics industry               Apple                                   4
# Healthcare                         UnitedHealth Group                      5
#                                    CVS Health                              6
# Conglomerate                       Berkshire Hathaway                      7
# Technology and cloud computing     Alphabet                                8
# Health                             McKesson Corporation                    9
# Petroleum industry                 Chevron Corporation                    10
# Pharmaceutical industry            AmerisourceBergen                      11
# ...

# %%
df2.sort_index()
# Out:
#                                                                         Rank  \
# Industry                           Name
# Aerospace and defense              Boeing                                 60
#                                    Lockheed Martin                        62
# Agriculture cooperative            CHS                                    92
# Agriculture manufacturing          John Deere                             83
# Airline                            American Airlines                      91
#                                    Delta Air Lines                        87
#                                    United Airlines                        98
# Apparel                            Nike                                   95
# Automotive and energy              Tesla                                  50
# Automotive industry                Ford Motor Company                     19
#                                    General Motors                         21
# ...

# %%
df2.loc['Financials','Citigroup']
# Out:
# Rank                                           36
# Revenue (USD millions)                    101,078
# Revenue growth                              26.6%
# Employees                                 238,104
# Headquarters              New York City, New York
# Name: (Financials, Citigroup), dtype: object

# %%
group_by_ind= df.groupby('Industry')

# %%
group_by_ind.mean()
# Out:
#                                          Rank
# Industry
# Aerospace and defense               61.000000
# Agriculture cooperative             92.000000
# Agriculture manufacturing           83.000000
# Airline                             92.000000
# Apparel                             95.000000
# Automotive and energy               50.000000
# Automotive industry                 20.000000
# Beverage                            46.000000
# Chemical industry                   77.000000
# Conglomerate                        40.000000
# Conglomerate and telecomunications  30.000000
# Consumer products manufacturing     51.000000
# Electronics industry                 4.000000
# Financial                           82.000000
# Financial services                  23.000000
# Financials                          48.727273
# Food industry                       46.500000
# Food processing                     87.500000
# Food service                        57.000000
# ...

# %%
group_by_ind.count()
# Out:
#                                     Rank  Name  Revenue (USD millions)  \
# Industry
# Aerospace and defense                  2     2                       2
# Agriculture cooperative                1     1                       1
# Agriculture manufacturing              1     1                       1
# Airline                                3     3                       3
# Apparel                                1     1                       1
# Automotive and energy                  1     1                       1
# Automotive industry                    2     2                       2
# Beverage                               1     1                       1
# Chemical industry                      1     1                       1
# Conglomerate                           3     3                       3
# Conglomerate and telecomunications     1     1                       1
# Consumer products manufacturing        1     1                       1
# ...

# %%
group_by_ind.max()
# Out:
#                                     Rank                                 Name  \
# Industry
# Aerospace and defense                 62                      Lockheed Martin
# Agriculture cooperative               92                                  CHS
# Agriculture manufacturing             83                           John Deere
# Airline                               98                      United Airlines
# Apparel                               95                                 Nike
# Automotive and energy                 50                                Tesla
# Automotive industry                   21                       General Motors
# Beverage                              46                              PepsiCo
# Chemical industry                     77                 Dow Chemical Company
# Conglomerate                          59                      RTX Corporation
# Conglomerate and telecomunications    30                                 AT&T
# ...

# %%
df['Revenue (USD millions)'] = original_df['Revenue (USD millions)'].copy()

df
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                           ExxonMobil
# 3      4                                Apple
# 4      5                   UnitedHealth Group
# 5      6                           CVS Health
# 6      7                   Berkshire Hathaway
# 7      8                             Alphabet
# 8      9                 McKesson Corporation
# 9     10                  Chevron Corporation
# 10    11                    AmerisourceBergen
# 11    12                               Costco
# 12    13                            Microsoft
# 13    14                      Cardinal Health
# 14    15                                Cigna
# 15    16                   Marathon Petroleum
# 16    17                          Phillips 66
# 17    18                        Valero Energy
# 18    19                   Ford Motor Company
# ...

# %%
df['Revenue (USD millions)'] = df['Revenue (USD millions)'].str.replace(',','').astype(int)

# %%
group_by_ind.agg({'Revenue (USD millions)':['mean','max','count','sum']})
# Out:
#                                    Revenue (USD millions)                \
#                                                      mean     max count
# Industry
# Aerospace and defense                        66296.000000   66608     2
# Agriculture cooperative                      47194.000000   47194     1
# Agriculture manufacturing                    52577.000000   52577     1
# Airline                                      48169.333333   50582     3
# Apparel                                      46710.000000   46710     1
# Automotive and energy                        81462.000000   81462     1
# Automotive industry                         157396.000000  158057     2
# Beverage                                     86859.000000   86859     1
# Chemical industry                            56902.000000   56902     1
# Conglomerate                                148572.666667  302089     3
# Conglomerate and telecomunications          120741.000000  120741     1
# ...

# %%
df.groupby('Name').describe()
# Out:
#                                      Rank                                  \
#                                     count   mean std    min    25%    50%
# Name
# AIG                                   1.0   78.0 NaN   78.0   78.0   78.0
# AT&T                                  1.0   30.0 NaN   30.0   30.0   30.0
# AbbVie                                1.0   75.0 NaN   75.0   75.0   75.0
# Albertsons                            1.0   53.0 NaN   53.0   53.0   53.0
# Allstate                              1.0   86.0 NaN   86.0   86.0   86.0
# Alphabet                              1.0    8.0 NaN    8.0    8.0    8.0
# Amazon                                1.0    2.0 NaN    2.0    2.0    2.0
# American Airlines                     1.0   91.0 NaN   91.0   91.0   91.0
# American Express                      1.0   79.0 NaN   79.0   79.0   79.0
# AmerisourceBergen                     1.0   11.0 NaN   11.0   11.0   11.0
# Apple                                 1.0    4.0 NaN    4.0    4.0    4.0
# ...
